# %% [markdown]
# Resource: https://ouvert.canada.ca/data/fr/dataset/01754a88-4ea3-42dd-9683-99beb7556b9f

# %%
import re 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import sys
print("python version:", sys.version)
# Out:
# python version: 3.8.5 (default, Sep  4 2020, 02:22:02)
# [Clang 10.0.0 ]

# %%
loc_emplo = '/Users/apple/100days/Practice/14100092-eng/14100092.csv'

# %%
emplo_obj = pd.read_csv(loc_emplo)
print(type(emplo_obj))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
emplo_obj.head(10)
# Out:
#    REF_DATE     GEO           DGUID  \
# 0      2001  Canada  2016A000011124
# 1      2001  Canada  2016A000011124
# 2      2001  Canada  2016A000011124
# 3      2001  Canada  2016A000011124
# 4      2001  Canada  2016A000011124
# 5      2001  Canada  2016A000011124
# 6      2001  Canada  2016A000011124
# 7      2001  Canada  2016A000011124
# 8      2001  Canada  2016A000011124
# 9      2001  Canada  2016A000011124
#
#   North American Industry Classification System (NAICS)      UOM  UOM_ID  \
# 0                     Total employed, all industries     Persons     249
# 1                             Goods-producing sector     Persons     249
# 2             Agriculture [111-112, 1100, 1151-1152]     Persons     249
# 3  Forestry, fishing, mining, quarrying, oil and ...     Persons     249
# 4                                     Utilities [22]     Persons     249
# 5                                  Construction [23]     Persons     249
# ...

# %%
emplo_obj.tail(10)
# Out:
#        REF_DATE                          GEO          DGUID  \
# 28870      2020  Northeast, British Columbia  2011S05005980
# 28871      2020  Northeast, British Columbia  2011S05005980
# 28872      2020  Northeast, British Columbia  2011S05005980
# 28873      2020  Northeast, British Columbia  2011S05005980
# 28874      2020  Northeast, British Columbia  2011S05005980
# 28875      2020  Northeast, British Columbia  2011S05005980
# 28876      2020  Northeast, British Columbia  2011S05005980
# 28877      2020  Northeast, British Columbia  2011S05005980
# 28878      2020  Northeast, British Columbia  2011S05005980
# 28879      2020  Northeast, British Columbia  2011S05005980
#
#       North American Industry Classification System (NAICS)      UOM  UOM_ID  \
# 28870             Transportation and warehousing [48-49]     Persons     249
# 28871  Finance, insurance, real estate, rental and le...     Persons     249
# ...

# %%
emplo_obj.shape
# Out:
# (28880, 15)

# %%
emplo_obj.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID',
#        'North American Industry Classification System (NAICS)', 'UOM',
#        'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE',
#        'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
emplo_obj.dtypes
# Out:
# REF_DATE                                                   int64
# GEO                                                       object
# DGUID                                                     object
# North American Industry Classification System (NAICS)     object
# UOM                                                       object
# UOM_ID                                                     int64
# SCALAR_FACTOR                                             object
# SCALAR_ID                                                  int64
# VECTOR                                                    object
# COORDINATE                                               float64
# VALUE                                                    float64
# STATUS                                                    object
# SYMBOL                                                   float64
# TERMINATED                                               float64
# ...

# %%
emplo_obj.isnull().sum()
# Out:
# REF_DATE                                                     0
# GEO                                                          0
# DGUID                                                     2660
# North American Industry Classification System (NAICS)        0
# UOM                                                          0
# UOM_ID                                                       0
# SCALAR_FACTOR                                                0
# SCALAR_ID                                                    0
# VECTOR                                                       0
# COORDINATE                                                   0
# VALUE                                                     1443
# STATUS                                                   27437
# SYMBOL                                                   28880
# TERMINATED                                               28880
# DECIMALS                                                     0
# dtype: int64

# %%
emplo_obj.nlargest(20, 'VALUE')
# Out:
#        REF_DATE     GEO           DGUID  \
# 25992      2019  Canada  2016A000011124
# 24548      2018  Canada  2016A000011124
# 23104      2017  Canada  2016A000011124
# 21660      2016  Canada  2016A000011124
# 27436      2020  Canada  2016A000011124
# 20216      2015  Canada  2016A000011124
# 18772      2014  Canada  2016A000011124
# 17328      2013  Canada  2016A000011124
# 15884      2012  Canada  2016A000011124
# 14440      2011  Canada  2016A000011124
# 10108      2008  Canada  2016A000011124
# 12996      2010  Canada  2016A000011124
# 8664       2007  Canada  2016A000011124
# 11552      2009  Canada  2016A000011124
# 7220       2006  Canada  2016A000011124
# 5776       2005  Canada  2016A000011124
# 4332       2004  Canada  2016A000011124
# 2888       2003  Canada  2016A000011124
# 1444       2002  Canada  2016A000011124
# 25999      2019  Canada  2016A000011124
#
#       North American Industry Classification System (NAICS)      UOM  UOM_ID  \
# ...

# %%
columns_to_drop = ['VECTOR']
emplo_obj.drop(columns_to_drop,axis="columns", inplace=True)

# %%
emplo_obj.fillna({"STATUS": 0}, inplace=True)

# %%
emplo_obj.nsmallest(10, 'VALUE')
# Out:
#        REF_DATE                   GEO        DGUID  \
# 8763       2007  Prince Edward Island  2016A000211
# 11651      2009  Prince Edward Island  2016A000211
# 13095      2010  Prince Edward Island  2016A000211
# 14539      2011  Prince Edward Island  2016A000211
# 23203      2017  Prince Edward Island  2016A000211
# 24647      2018  Prince Edward Island  2016A000211
# 27535      2020  Prince Edward Island  2016A000211
# 1543       2002  Prince Edward Island  2016A000211
# 7319       2006  Prince Edward Island  2016A000211
# 10207      2008  Prince Edward Island  2016A000211
#
#       North American Industry Classification System (NAICS)      UOM  UOM_ID  \
# 8763                                      Utilities [22]     Persons     249
# 11651                                     Utilities [22]     Persons     249
# 13095                                     Utilities [22]     Persons     249
# 14539                                     Utilities [22]     Persons     249
# ...

# %%
emplo_obj.describe()
# Out:
#            REF_DATE   UOM_ID  SCALAR_ID    COORDINATE         VALUE  SYMBOL  \
# count  28880.000000  28880.0    28880.0  28880.000000  27437.000000     0.0
# mean    2010.500000    249.0        3.0     40.194737    112.042785     NaN
# std        5.766381      0.0        0.0     22.612322    686.365917     NaN
# min     2001.000000    249.0        3.0      1.100000      0.200000     NaN
# 25%     2005.750000    249.0        3.0     21.050000      4.200000     NaN
# 50%     2010.500000    249.0        3.0     40.000000     11.400000     NaN
# 75%     2015.250000    249.0        3.0     59.950000     41.700000     NaN
# max     2020.000000    249.0        3.0     79.900000  19055.700000     NaN
#
#        TERMINATED  DECIMALS
# count         0.0   28880.0
# mean          NaN       1.0
# std           NaN       0.0
# min           NaN       1.0
# 25%           NaN       1.0
# 50%           NaN       1.0
# 75%           NaN       1.0
# max           NaN       1.0

# %%
emplo_obj.groupby(by=['GEO']).size()
# Out:
# GEO
# Abitibi-Témiscamingue, Quebec                                                          380
# Alberta                                                                                380
# Annapolis Valley, Nova Scotia                                                          380
# Avalon Peninsula, Newfoundland and Labrador                                            380
# Banff-Jasper-Rocky Mountain House and Athabasca-Grande Prairie-Peace River, Alberta    380
#                                                                                       ...
# West Coast-Northern Peninsula-Labrador, Newfoundland and Labrador                      380
# Windsor-Sarnia, Ontario                                                                380
# Winnipeg, Manitoba                                                                     380
# Wood Buffalo-Cold Lake, Alberta                                                        380
# ...

# %%
Relative = {'count': emplo_obj.groupby(by=['GEO', 'VALUE']).size()}
value_per_GEO = pd.DataFrame(Relative).reset_index() 
value_per_GEO
# Out:
#                                   GEO  VALUE  count
# 0       Abitibi-Témiscamingue, Quebec    1.5      4
# 1       Abitibi-Témiscamingue, Quebec    1.6      6
# 2       Abitibi-Témiscamingue, Quebec    1.7      2
# 3       Abitibi-Témiscamingue, Quebec    1.8      3
# 4       Abitibi-Témiscamingue, Quebec    1.9      7
# ...                               ...    ...    ...
# 15863  Yorkton-Melville, Saskatchewan   40.2      1
# 15864  Yorkton-Melville, Saskatchewan   40.4      1
# 15865  Yorkton-Melville, Saskatchewan   41.3      1
# 15866  Yorkton-Melville, Saskatchewan   41.7      1
# 15867  Yorkton-Melville, Saskatchewan   41.9      1
#
# [15868 rows x 3 columns]
